# %% [markdown]
# **Numbers**

# %%
2+1
# Out:
# 3

# %%
2-1
# Out:
# 1

# %%
2*2
# Out:
# 4

# %%
3/2
# Out:
# 1.5

# %% [markdown]
# **Modulo or "Mod" Operator**

# %%
7/4
# Out:
# 1.75

# %%
7 % 4
# Out:
# 3

# %%
50 % 5
# Out:
# 0

# %%
23 % 2
# Out:
# 1

# %%
20 % 2
# Out:
# 0

# %%
2 ** 3
# Out:
# 8

# %%
2 + 10 * 10 + 3
# Out:
# 105

# %%
(2+10) * (10+3)
# Out:
# 156

# %% [markdown]
# **Assignment and Data Types**

# %%
a = 5

# %%
a
# Out:
# 5

# %%
a = 10

# %%
a + a
# Out:
# 20

# %%
a
# Out:
# 10

# %%
a = a + a

# %% [markdown]
# this a + a  will sum the last value of the a

# %%
a
# Out:
# 40

# %%
type(a)
# Out:
# int

# %%
a = 1.5

# %%
type(a)
# Out:
# float

# %% [markdown]
# avoid using inbuilt keywords to use as variable

# %%
int = 4

# %%
my_income = 100
tax_rate = 0.1
my_tax = my_income * tax_rate

# %%
my_tax
# Out:
# 10.0

# %% [markdown]
# **Strings**

# %%
'HELLO'
# Out:
# 'HELLO'

# %%
"world"
# Out:
# 'world'

# %%
'this is also a string'
# Out:
# 'this is also a string'

# %%
' I'm going on a run'
# Out:
#   Cell In[35], line 1
#     ' I'm going on a run'
#                         ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
" I'm going on a run"
# Out:
# " I'm going on a run"

# %%
print("hello")
# Out:
# hello

# %%
"hello 1"
"hello 2"
# Out:
# 'hello 2'

# %%
print("hello 1")
print("hello 2")
# Out:
# hello 1
# hello 2

# %%
print("hello \n world")
# Out:
# hello
#  world

# %%
print("hello \t world")
# Out:
# hello 	 world

# %%
len("hello")
# Out:
# 5

# %%
len(" i am")
# Out:
# 5

# %% [markdown]
# **Indexing and Slicing**

# %%
mystring = "hello world"

# %%
mystring
# Out:
# 'hello world'

# %%
mystring[0]
# Out:
# 'h'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring
# Out:
# 'hello world'

# %%
mystring[-3]
# Out:
# 'r'

# %%
mystring = 'abcdefghijklmn'

# %%
mystring[0:]
# Out:
# 'abcdefghijklmn'

# %%
mystring[:]
# Out:
# 'abcdefghijklmn'

# %%
mystring[2:]
# Out:
# 'cdefghijklmn'

# %%
mystring[:4]
# Out:
# 'abcd'

# %%
mystring[3:6]
# Out:
# 'def'

# %%
mystring[1:3]
# Out:
# 'bc'

# %%
mystring[::]
# Out:
# 'abcdefghijklmn'

# %%
mystring[::2]
# Out:
# 'acegikm'

# %% [markdown]
# *2 is step size*

# %%
mystring[2:8:2]
# Out:
# 'ceg'

# %%
mystring
# Out:
# 'abcdefghijklmn'

# %%
mystring[::-1]
# Out:
# 'nmlkjihgfedcba'

# %%
mystring[::-2]
# Out:
# 'nljhfdb'

# %% [markdown]
# *here -1 and -2 are also step size but does the slicing from right side*

# %% [markdown]
# **String Properties and Methods**

# %% [markdown]
# ***Immutability***

# %%
name = "pratik"

# %%
name[0] = 's'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 name[0] = 's'
#
# TypeError: 'str' object does not support item assignment

# %%
last_letters = name[1:]

# %%
last_letters
# Out:
# 'ratik'

# %%
x = 'Hello world'

# %%
x + "it is cold outside"
# Out:
# 'Hello worldit is cold outside'

# %%
x + " it is cold outside"
# Out:
# 'Hello world it is cold outside'

# %%
x = x + " it is cold outside"

# %%
x
# Out:
# 'Hello world it is cold outside it is cold outside'

# %%
y = x + name

# %%
y
# Out:
# 'Hello world it is cold outside it is cold outsidepratik'

# %%
letter = 'z'

# %%
letter * 10
# Out:
# 'zzzzzzzzzz'

# %%
2 + 3
# Out:
# 5

# %%
'2' + '3'
# Out:
# '23'

# %% [markdown]
# ***methods***

# %%
x = "hello world"

# %%
x.capitalize()
# Out:
# 'Hello world'

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x
# Out:
# 'hello world'

# %%
x = x.upper()

# %%
x
# Out:
# 'HELLO WORLD'

# %%
x = x.lower()

# %%
x
# Out:
# 'hello world'

# %%
x.split()
# Out:
# ['hello', 'world']

# %% [markdown]
# *default split is perform on white space*

# %%
x.split('l')
# Out:
# ['he', '', 'o wor', 'd']

# %% [markdown]
# ***String formatting for printing***

# %%
print('hello')
# Out:
# hello

# %% [markdown]
# *Formatting with the .format() method*
#
# *A better way to format objects into your strings for print statements is with the string .format() method. The syntax is:*
#
#
# *'String here {} then also {}'.format('something1','something2')*

# %%
print("this is string {}".format("INSERTED"))
# Out:
# this is string INSERTED

# %%
print('The {} {} {}'.format('fox', 'brown', 'quick'))
# Out:
# The fox brown quick

# %%
print('The {2} {1} {0}'.format('fox', 'brown', 'quick'))
# Out:
# The quick brown fox

# %%
print('The {0} {0} {0}'.format('fox', 'brown', 'quick'))
# Out:
# The fox fox fox

# %%
name = 'pratik'

# %%
print('name is {0}'.format(name))
# Out:
# name is pratik

# %%
print('the {q} {b} {f}'.format(f='fox', b='brown', q='quick'))
# Out:
# the quick brown fox

# %% [markdown]
# *float formating follows "{values:width.precision f}"*

# %%
result = 100 / 700

# %%
result
# Out:
# 0.14285714285714285

# %%
print("the result was {}".format(result))
# Out:
# the result was 0.14285714285714285

# %%
print("the result was {r:10.3f}".format(r=result))
# Out:
# the result was      0.143

# %% [markdown]
# *this width value 10 add white spaces*
#
# *precision is for how many numbers after the point*

# %%
r = 105.124645
print("the value is {r:1.3f}".format(r=r))
# Out:
# the value is 105.125

# %% [markdown]
# *f string method*

# %%
name
# Out:
# 'pratik'

# %%
print(f"hello, his name is {name}")
# Out:
# hello, his name is pratik

# %%
age = 21
print(f"his name is {name} and he is {age} years old")
# Out:
# his name is pratik and he is 21 years old

# %% [markdown]
# **Lists**

# %%
my_list = [1,2,3,4,5]

# %%
my_list
# Out:
# [1, 2, 3, 4, 5]

# %%
my_list = ['string',1,2.3,5,100,600]

# %%
my_list
# Out:
# ['string', 1, 2.3, 5, 100, 600]

# %%
len(my_list)
# Out:
# 6

# %%
my_list[0]
# Out:
# 'string'

# %%
my_list[1:]
# Out:
# [1, 2.3, 5, 100, 600]

# %%
my_list
# Out:
# ['string', 1, 2.3, 5, 100, 600]

# %%
anpother_list = ['one','two','three']

# %%
anpother_list + my_list
# Out:
# ['one', 'two', 'three', 'string', 1, 2.3, 5, 100, 600]

# %%
new_list = my_list + anpother_list

# %%
new_list
# Out:
# ['string', 1, 2.3, 5, 100, 600, 'one', 'two', 'three']

# %%
my_list[2] = 5.9

# %%
my_list
# Out:
# ['string', 1, 5.9, 5, 100, 600]

# %%
new_list[6] = 'ONE'
new_list
# Out:
# ['string', 1, 2.3, 5, 100, 600, 'ONE', 'two', 'three']

# %%
new_list.append('four')
new_list
# Out:
# ['string', 1, 2.3, 5, 100, 600, 'ONE', 'two', 'three', 'four', 'four']

# %%
new_list.append('five')
new_list
# Out:
# ['string', 1, 2.3, 5, 100, 600, 'ONE', 'two', 'three', 'four', 'four', 'five']

# %%
new_list.pop()
# Out:
# 'five'

# %% [markdown]
# *by default -1 is indexing in pop, so here reverse indexing also work*

# %%
new_list
# Out:
# ['string', 1, 2.3, 5, 100, 600, 'ONE', 'two', 'three', 'four', 'four']

# %%
new_list.pop(8)
# Out:
# 'three'

# %%
new_list
# Out:
# ['string', 1, 2.3, 5, 100, 600, 'ONE', 'two', 'four', 'four']

# %%
new_list.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 new_list.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
num_list = [4,6,89,46,24,3]
alph_list = ['a','x','d','y']

# %%
num_list.sort()

# %% [markdown]
# *.sort is inplace method it does not return anything*

# %%
num_list
# Out:
# [3, 4, 6, 24, 46, 89]

# %%
alph_list.sort()
alph_list
# Out:
# ['a', 'd', 'x', 'y']

# %%
type(num_list)
# Out:
# list

# %%
sorted_num_list = num_list.sort()
type(sorted_num_list)
# Out:
# NoneType

# %% [markdown]
# *reverse method is also inplace method*

# %%
num_list.reverse()
num_list
# Out:
# [3, 4, 6, 24, 46, 89]

# %% [markdown]
# **Dictonaries**

# %%
dict = {'key1':'value1', 'key2':'value2'} 
dict
# Out:
# {'key1': 'value1', 'key2': 'value2'}

# %%
dict['key1']
# Out:
# 'value1'

# %%
prices_lookup = {'apple':40, 'oranges':30, 'chocalate':10}
prices_lookup['chocalate']
# Out:
# 10

# %%
d = {'k1':123, 'k2':[1,2,3],'k3':{'insidekey':100}}
d
# Out:
# {'k1': 123, 'k2': [1, 2, 3], 'k3': {'insidekey': 100}}

# %%
d['k2']
# Out:
# [1, 2, 3]

# %%
d['k2'][1]
# Out:
# 2

# %%
d['k3']
# Out:
# {'insidekey': 100}

# %%
d['k3']['insidekey']
# Out:
# 100

# %%
d1 = {'k1':['a','b','c']}

# %%
d1['k1'][1].upper()
# Out:
# 'B'

# %%
d2 = {'k1':100, 'k2':200}
d2
# Out:
# {'k1': 100, 'k2': 200}

# %%
d2['k3'] = 300
d2
# Out:
# {'k1': 100, 'k2': 200, 'k3': 300}

# %%
d2['k1'] = 'new value'
d2
# Out:
# {'k1': 'new value', 'k2': 200, 'k3': 300}

# %%
d2.keys()
# Out:
# dict_keys(['k1', 'k2', 'k3'])

# %%
d2.values()
# Out:
# dict_values(['new value', 200, 300])

# %%
d2.items()
# Out:
# dict_items([('k1', 'new value'), ('k2', 200), ('k3', 300)])

# %% [markdown]
# **Tupels(immutable)**

# %%
t = (1,2,3,4,5)
t
# Out:
# (1, 2, 3, 4, 5)

# %%
l = [1,2,3,4,5]
l
# Out:
# [1, 2, 3, 4, 5]

# %%
print(type(t))
print(type(l))
# Out:
# <class 'tuple'>
# <class 'list'>

# %%
t = ('one',2)
t
# Out:
# ('one', 2)

# %%
t[0]
# Out:
# 'one'

# %%
t[-1]
# Out:
# 2

# %%
t[::]
# Out:
# ('one', 2)

# %%
t = ('a','a','a','b','b','c')
t
# Out:
# ('a', 'a', 'a', 'b', 'b', 'c')

# %%
t.count('a')
# Out:
# 3

# %% [markdown]
# *index method return the index position that very first time a occured in a list*

# %%
t.index('a')
# Out:
# 0

# %%
t.index('b')
# Out:
# 3

# %%
t[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[208], line 1
# ----> 1 t[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# **Sets (immutable and unordered collection of unique elements)**

# %%
s = set()

# %%
s
# Out:
# set()

# %%
s.add(1)
s
# Out:
# {1}

# %%
s.add(2)
s
# Out:
# {1, 2}

# %%
s.add(2)
s
# Out:
# {1, 2}

# %%
l1 = [1,1,1,1,2,2,3,4,4,5,5,6]
l1
# Out:
# [1, 1, 1, 1, 2, 2, 3, 4, 4, 5, 5, 6]

# %%
set(l1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
print(l1)
# Out:
# [1, 1, 1, 1, 2, 2, 3, 4, 4, 5, 5, 6]

# %%
l1 = set(l1)
print(l1)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
l1
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# *here any random item is poped rather than last one from the set because sets are unordered*

# %%
l1.pop()
# Out:
# 1

# %% [markdown]
# **Booleans**

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
1 > 2
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
b = None

# %%
b

# %%
type(b)
# Out:
# NoneType

# %% [markdown]
# **I/O Operations**

# %% [markdown]
# mode='r' is read only
#
# mode='w' is write only
#
# mode='a' is append only
#
# mode='r+' is reading and writing
#
# mode='w+' is writing and reading
#
# 'x'	create a new file and open it for writing
#
# 'a'	open for writing, appending to the end of the file if it exists
#
# 'b'	binary mode
#
# 't'	text mode (default)
#
# '+'	open a disk file for updating (reading and writing)

# %%
# %%writefile myfile.txt
# hello this is text file
# first line
# second line
# Out:
# Overwriting myfile.txt

# %%
myfile = open('myfile.txt')

# %%
myfile = open('wrong.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[247], line 1
# ----> 1 myfile = open('wrong.txt')
#
# File c:\Users\PratikJPatel\Desktop\Training\Crest-Training\venv\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'wrong.txt'

# %%
myfile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='r' encoding='cp1252'>

# %%
pwd
# Out:
# 'c:\\Users\\PratikJPatel\\Desktop\\Training\\Crest-Training\\01-Python_Bootcamp\\03-Python_Object_and_Data_Structure'

# %%
myfile = open('myfile.txt')

# %%
myfile.read()
# Out:
# 'hello this is text file\nfirst line\nsecond line\n'

# %% [markdown]
# *after reading one time the file*
#
# *curser will go to the end of the file*

# %%
myfile.read()
# Out:
# ''

# %% [markdown]
# *reseting the cursur*

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'hello this is text file\nfirst line\nsecond line\n'

# %%
content = myfile.read()

# %%
content
# Out:
# 'hello this is text file\nfirst line\nsecond line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['hello this is text file\n', 'first line\n', 'second line\n']

# %%
myfile.seek(0)
myfile.readline()
# Out:
# 'hello this is text file\n'

# %%
myfile.close()

# %% [markdown]
# *to avoid manually closing of the file use with function*

# %%
with open('myfile.txt') as newfile:
    contents = newfile.read()

# %%
contents
# Out:
# 'hello this is text file\nfirst line\nsecond line\n'

# %%
with open('myfile.txt',mode='r') as myfile:
    contents = myfile.read()
contents
# Out:
# 'hello this is text file\nfirst line\nsecond line\n'

# %%
with open('myfile.txt',mode='w') as myfile:
    contents = myfile.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[276], line 2
#       1 with open('myfile.txt',mode='w') as myfile:
# ----> 2     contents = myfile.read()
#
# UnsupportedOperation: not readable

# %%
# %%writefile my_new_file.txt
# one on first
# two on second
# three on third
# Out:
# Writing my_new_file.txt

# %%
with open('my_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# one on first
# two on second
# three on third

# %%
with open('my_new_file.txt',mode='a') as f:
    f.write('four on fourth')

# %%
with open('my_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# one on first
# two on second
# three on third
# four on fourth

# %%
with open('a_new_file.txt',mode='w') as f:
    f.write('i created the file')

# %%
with open('a_new_file.txt',mode='r') as f:
    print(f.read())
# Out:
# i created the file
