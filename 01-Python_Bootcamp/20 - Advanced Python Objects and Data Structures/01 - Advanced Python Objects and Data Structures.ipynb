# %% [markdown]
# **Advanced Numbers**

# %% [markdown]
# Hexa decimal

# %%
hex(12)
# Out:
# '0xc'

# %%
hex(5120)
# Out:
# '0x1400'

# %% [markdown]
# Binary

# %%
bin(128)
# Out:
# '0b10000000'

# %%
bin(2)
# Out:
# '0b10'

# %%
2 ** 4
# Out:
# 16

# %%
pow(2,4,3) #(x^y) % z => (2 ^ 4) % 3
# Out:
# 1

# %%
abs(-1)
# Out:
# 1

# %%
round(3.1)
# Out:
# 3

# %%
round(3)
# Out:
# 3

# %%
round(3.141592,2)
# Out:
# 3.14

# %% [markdown]
# **Advanced Strings**

# %%
s = 'hello world'

# %%
s.capitalize()
# Out:
# 'Hello world'

# %%
s.upper()
# Out:
# 'HELLO WORLD'

# %%
s.lower()
# Out:
# 'hello world'

# %%
s.count('o')
# Out:
# 2

# %%
s.find('o') #fisrt occurence of 'o' at which index it will return that
# Out:
# 4

# %%
s
# Out:
# 'hello world'

# %%
s.center(20,'z')
# Out:
# 'zzzzhello worldzzzzz'

# %%
'hello\thi'
# Out:
# 'hello\thi'

# %%
print ('hello\thi')
# Out:
# hello	hi

# %%
'hello\thi'.expandtabs()
# Out:
# 'hello   hi'

# %%
s = 'hello'

# %%
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s.isupper()
# Out:
# False

# %%
s.isspace()
# Out:
# False

# %%
s.istitle()
# Out:
# False

# %%
s.endswith('o')
# Out:
# True

# %%
s[-1]
# Out:
# 'o'

# %%
s.split('e')
# Out:
# ['h', 'llo']

# %%
s = 'hihihihiiiii'

# %%
s.partition('i')
# Out:
# ('h', 'i', 'hihihiiiii')

# %% [markdown]
# **Advanced Sets**

# %%
s = set()

# %%
s.add(1)

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %%
s.add(2)

# %%
s
# Out:
# {1, 2}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
s = {12,2,3,5,}

# %%
sc = s.copy()

# %%
sc
# Out:
# {2, 3, 5, 12}

# %%
s.add(4)

# %%
sc
# Out:
# {2, 3, 5, 12}

# %%
s
# Out:
# {2, 3, 4, 5, 12}

# %%
s.difference(sc)
# Out:
# {4}
