# %% [markdown]
# **Comparision operators**

# %%
2  == 2
# Out:
# True

# %%
2 == 1
# Out:
# False

# %%
'hello' == 'bye'
# Out:
#   Cell In[3], line 1
#     'hello' = 'bye'
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
'bye' == 'BYE'
# Out:
# False

# %%
'2'  == 2
# Out:
# False

# %%
2.0 == 2
# Out:
# True

# %%
3 != 3
# Out:
# False

# %%
4 != 5
# Out:
# True

# %%
2 > 3
# Out:
# False

# %%
2 < 3
# Out:
# True

# %%
2 >= 3
# Out:
# False

# %%
2 <= 3
# Out:
# True

# %% [markdown]
# **Logical Operators**
#
# and, or, not

# %%
1 < 2 < 3
# Out:
# True

# %%
1 < 2 > 3
# Out:
# False

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
('h' == 'h') and (2 == 2)
# Out:
# True

# %%
1 < 2 and 2 > 3
# Out:
# False

# %%
1 < 2 or 2 > 3
# Out:
# True

# %%
1 == 1 or 5 > 4
# Out:
# True

# %%
1 != 1 or 3 > 100
# Out:
# False

# %%
1 == 1
# Out:
# True

# %%
not(1 == 1)
# Out:
# False

# %%
not 1 == 1
# Out:
# False

# %%
400 > 5000
# Out:
# False

# %%
not 400 > 5000
# Out:
# True
