# %% [markdown]
# **Methods**

# %%
my_list = [1,2,3]

# %%
my_list.append(4)

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %%
my_list.pop()
my_list
# Out:
# [1, 2, 3]

# %%
my_list.insert()

# %% [markdown]
# **Functions**

# %%
def say_hello():
    print('hello')

# %%
say_hello()
# Out:
# hello

# %%
say_hello
# Out:
# <function __main__.say_hello()>

# %%
def say_hello(name):
    print(f"hello {name}")

# %%
say_hello('pratik')
# Out:
# hello pratik

# %%
def add_num(num1,num2):
    return num1 + num2

# %%
add_num(10,20)
# Out:
# 30

# %%
result  = add_num(10,20)

# %%
print((result))
# Out:
# 30

# %%
add_num('10','20')
# Out:
# '1020'

# %% [markdown]
# **Functions with logic**

# %%
2 % 2
# Out:
# 0

# %%
3 % 2
# Out:
# 1

# %%
20 % 2 == 0
# Out:
# True

# %%
def even_check(num):
    return num % 2 == 0

# %%
even_check(22)
# Out:
# True

# %%
even_check(41)
# Out:
# False

# %%
def check_even_list(num_list):
    for i in num_list:
        if i % 2 == 0:
            return True
        else:
            pass

# %%
check_even_list([1,2,3,4,5,6])
# Out:
# True

# %%
check_even_list([1,3,5])

# %%
check_even_list([2,4,6])
# Out:
# True

# %%
check_even_list([2])
# Out:
# True

# %%
def check_even_list(num_list):
    for i in num_list:
        if i % 2 == 0:
            return True
        else:
            pass
    return False

# %%
check_even_list([1,2,5])
# Out:
# True

# %%
check_even_list([1,3,5])
# Out:
# False

# %%
def check_even_list(num_list):

    even_numbers = []

    for i in num_list:
        if i % 2 == 0:
            even_numbers.append(i)
        else:
            pass
    return even_numbers

# %%
check_even_list([1,2,3,4,5,6])
# Out:
# [2, 4, 6]

# %%
stock_price = [('apple',200),('gog',400),('mst',100)]

# %%
for i in stock_price:
    print(i)
# Out:
# ('apple', 200)
# ('gog', 400)
# ('mst', 100)

# %%
for ticker,price in stock_price:
    print(ticker)
# Out:
# apple
# gog
# mst

# %%
for ticker,price in stock_price:
    print(0.1*price)
# Out:
# 20.0
# 40.0
# 10.0

# %%
work_hours = [ ('abhy',100),('billy',150),('joy',125)]

# %%
def employee_of_month(work_hours):

    current_max = 0
    employee_of_month = ''

    for name,hours in work_hours:
        if hours > current_max:
            current_max = hours
            employee_of_month = name
    return(employee_of_month,current_max)

# %%
employee_of_month(work_hours)
# Out:
# ('billy', 150)

# %%
result = employee_of_month(work_hours)

# %%
result
# Out:
# ('billy', 150)

# %%
name,hours = employee_of_month(work_hours)

# %%
name
# Out:
# 'billy'

# %%
hours
# Out:
# 150

# %%
name,hours, location = employee_of_month(work_hours)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 name,hours, location = employee_of_month(work_hours)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %% [markdown]
# **Interaction between Functions**

# %%
example = [1,2,3,4,5,6,7]

# %%
from random import shuffle

# %%
shuffle(example)

# %%
example
# Out:
# [2, 3, 6, 5, 4, 1, 7]

# %%
def shuffle_list(my_list):
    shuffle(my_list)
    return my_list

# %%
result = shuffle_list(example)
print(result)
# Out:
# [7, 1, 5, 4, 3, 6, 2]

# %%
my_list = ['','','o']

# %%
shuffle_list(my_list)
# Out:
# ['', 'o', '']

# %%
def player_guess():
    guess = ''

    while guess not in ['0','1','2']:
        guess = input('pick a number 0,1 or 2')
    
    return int(guess)

# %%
player_guess()
# Out:
# 2

# %%
def check_guess(my_list,guess):
    if my_list[guess]  == 'o':
        print('correct')
    else:
        print('wrong guess')
        print(my_list)

# %%
#initial list
my_list = ['','o','']

#shuffle list
mixedup_list = shuffle_list(my_list)

#user guess
guess = player_guess()

#check guess
check_guess(mixedup_list,guess)
# Out:
# correct

# %% [markdown]
# ***args and** ****kwargs**

# %%
def my_func(a, b,c=0, d=0, e=0):
    return sum((a,b,c,d,e))*0.05

# %%
my_func(40,60,100)
# Out:
# 10.0

# %%
def myfunc(*args):
    return sum(args) * 0.05

# %%
myfunc(40,60,5,100)
# Out:
# 10.25

# %%
def myfunc(*args):
    for i in args:
        print(i)

# %%
myfunc(10,60,546,54)
# Out:
# 10
# 60
# 546
# 54

# %%
def myfunc(**kwargs):
    print(kwargs)
    if 'fruit' in kwargs:
        print(1)
    else:
        print(0)

# %%
myfunc(fruit='apple',veggie='potato',maggie='nestle')
# Out:
# {'fruit': 'apple', 'veggie': 'potato', 'maggie': 'nestle'}
# 1

# %% [markdown]
# **Lambda function , map and filter function**

# %%
def square(num):
    return num ** 2

# %%
my_nums = [1,2,3,4,6]

# %%
map(square,my_nums)

# %%
for item in map(square,my_nums):
    print(item)
# Out:
# 1
# 4
# 9
# 16
# 36

# %%
def splicer(mystring):
    if len(mystring)%2 == 0:
        return 'Even'
    else:
        return mystring

# %%
names = ['ady','peter','tony']

# %%
list(map(splicer,names))
# Out:
# ['ady', 'peter', 'Even']

# %%
def check_even(num):
    return num%2 == 0

# %%
mynums = [1,2,3,4,5,6]

# %%
filter(check_even,my_nums)

# %%
for i in filter(check_even,my_nums):
    print(i)
# Out:
# 2
# 4
# 6

# %%
def square(num):
    return num ** 2

# %%
def square(num) : return num ** 2

# %%
square(3)
# Out:
# 9

# %%
square = lambda num: num ** 2

# %%
square(5)
# Out:
# 25

# %%
list(map(lambda num:num ** 2,my_nums))
# Out:
# [1, 4, 9, 16, 36]

# %%
list(filter(lambda num : num % 2 == 0,mynums))
# Out:
# [2, 4, 6]

# %% [markdown]
# **Nested Statements and Scopes**

# %%
x = 25
def printer():
    x=50
    return x

# %%
print(x)
# Out:
# 25

# %%
print(printer())
# Out:
# 50

# %% [markdown]
# LEGB Rule:
#
# L: Local — Names assigned in any way within a function (def or lambda), and not declared global in that function.
#
# E: Enclosing function locals — Names in the local scope of any and all enclosing functions (def or lambda), from inner to outer.
#
# G: Global (module) — Names assigned at the top-level of a module file, or declared global in a def within the file.
#
# B: Built-in (Python) — Names preassigned in the built-in names module : open, range, SyntaxError,...

# %% [markdown]
# *Local*

# %%
# x is local here:
f = lambda x:x**2

# %% [markdown]
# *Enclosing function locals*
#
# This occurs when we have a function inside a function (nested functions)

# %%
name = 'This is a global name'

def greet():
    # Enclosing function
    name = 'Sammy'
    
    def hello():
        print('Hello '+name)
    
    hello()

greet()
# Out:
# Hello Sammy

# %% [markdown]
# *Global*
#
# Luckily in Jupyter a quick way to test for global variables is to see if another cell recognizes the variable!

# %%
print(name)
# Out:
# This is a global name

# %% [markdown]
# *Local Variables*

# %%
x = 50

def func(x):
    print('x is', x)
    x = 2
    print('Changed local x to', x)

func(x)
print('x is still', x)
# Out:
# x is 50
# Changed local x to 2
# x is still 50

# %% [markdown]
# *The global statement*

# %%
x = 50

def func():
    global x
    print('This function is now using the global x!')
    print('Because of global x is: ', x)
    x = 2
    print('Ran func(), changed global x to', x)

print('Before calling func(), x is: ', x)
func()
print('Value of x (outside of func()) is: ', x)
# Out:
# Before calling func(), x is:  50
# This function is now using the global x!
# Because of global x is:  50
# Ran func(), changed global x to 2
# Value of x (outside of func()) is:  2
