# %%
import smtplib

# %%
smtp_object = smtplib.SMTP('smtp.gmail.com',587)

# %%
smtp_object.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [123.201.110.130]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
smtp_object.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
input('what is your password:')
# Out:
# 'visible'

# %%
import getpass

# %%
password = getpass.getpass('Password:')

# %% [markdown]
# **Sending email**

# %%
email = getpass.getpass('Email:')
password = getpass.getpass('password:')
smtp_object.login(email,password)
# Out:
# (235, b'2.7.0 Accepted')

# %%
from_address = email
to_address = email
subject_line = input('enter subject line:')
message = input('enter body message:')
msg = 'subject:' + subject_line + '\n' + message

smtp_object.sendmail(from_address,to_address,msg)
# Out:
# {}

# %%
smtp_object.quit()
# Out:
# (221,
#  b'2.0.0 closing connection 98e67ed59e1d1-34f5fb74436sm1241793a91.14 - gsmtp')

# %% [markdown]
# **Recieving email**

# %%
import imaplib

# %%
m = imaplib.IMAP4_SSL('imap.gmail.com')

# %%
email = getpass.getpass('Email:')
password = getpass.getpass('password:')

# %%
m.login(email,password)
# Out:
# ('OK', [b'pratik.p@crestskillserve.com authenticated (Success)'])

# %%
m.list()
# Out:
# ('OK',
#  [b'(\\HasNoChildren) "/" "INBOX"',
#   b'(\\HasChildren \\Noselect) "/" "[Gmail]"',
#   b'(\\All \\HasNoChildren) "/" "[Gmail]/All Mail"',
#   b'(\\Drafts \\HasNoChildren) "/" "[Gmail]/Drafts"',
#   b'(\\HasNoChildren \\Important) "/" "[Gmail]/Important"',
#   b'(\\HasNoChildren \\Sent) "/" "[Gmail]/Sent Mail"',
#   b'(\\HasNoChildren \\Junk) "/" "[Gmail]/Spam"',
#   b'(\\Flagged \\HasNoChildren) "/" "[Gmail]/Starred"',
#   b'(\\HasNoChildren \\Trash) "/" "[Gmail]/Trash"'])

# %%
m.select('inbox')
# Out:
# ('OK', [b'27'])

# %%
type, data = m.search(None,'SUBJECT "new python test"')

# %% [markdown]
# *here this subject "new python test" is case sensitive*

# %%
type
# Out:
# 'OK'

# %%
data
# Out:
# [b'27']

# %%
data[0]
# Out:
# b'27'

# %%
email_id = data[0]

# %%
result , email_data = m.fetch(email_id,'(RFC822)')

# %%
email_data
# Out:
# [(b'27 (RFC822 {587}',
#   b'Bcc: pratik.p@crestskillserve.com\r\nReturn-Path: <pratik.p@crestskillserve.com>\r\nReceived: from [192.168.0.169] ([123.201.110.130])\r\n        by smtp.gmail.com with ESMTPSA id 98e67ed59e1d1-34f5fb74436sm1241793a91.14.2026.01.12.20.25.52\r\n        for <pratik.p@crestskillserve.com>\r\n        (version=TLS1_3 cipher=TLS_AES_256_GCM_SHA384 bits=256/256);\r\n        Mon, 12 Jan 2026 20:25:53 -0800 (PST)\r\nMessage-ID: <6965c951.170a0220.25b93b.afc0@mx.google.com>\r\nDate: Mon, 12 Jan 2026 20:25:53 -0800 (PST)\r\nFrom: pratik.p@crestskillserve.com\r\nsubject:new python test\r\n\r\nhello this is a test \r\n'),
#  b')']

# %%
raw_email = email_data[0][1]

# %%
raw_email_string = raw_email.decode('utf-8')

# %%
import email

# %%
email_message = email.message_from_string(raw_email_string)

# %%
email_message

# %%
for part in email_message.walk():
    if part.get_content_type() == 'text/plain':
        body = part.get_payload(decode = True)
        print(body)
# Out:
# b'hello this is a test \r\n'
