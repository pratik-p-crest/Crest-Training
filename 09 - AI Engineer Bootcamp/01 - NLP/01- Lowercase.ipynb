# %%
sentence = "Her cat name is Billu"

# %%
sentence
# Out:
# 'Her cat name is Billu'

# %%
lower_case_sentence = sentence.lower()

# %%
lower_case_sentence
# Out:
# 'her cat name is billu'

# %%
sentence_list = ['pass Me the Remote',
                 'it is Nice',
                 'Want to go on Holiday']

# %%
lower_sentence_list =  [x.lower() for x in sentence_list]

# %%
lower_sentence_list
# Out:
# ['pass me the remote', 'it is nice', 'want to go on holiday']
