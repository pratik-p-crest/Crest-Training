# %% [markdown]
# **Linear Search**

# %%
list = [3,4,7,89,1,0,5,8]
def linear_search(list,item):
    for i in list:
        if item == i:
            return "Found"

    return "Not Found"

linear_search(list,89)
# Out:
# 'Found'

# %% [markdown]
# **Binary Search**

# %%
l = [1,2,4,6,441,41,3,1,54,63,44,6,46]

# %%
def binary_search(l, item):
    l.sort()

    length = len(l)
    left = 0
    right = length - 1

    while left <= right:

        mid = (left + right) // 2

        if list[mid] == item:
            return f"Found the item {item}"
        
        elif list[mid] > item:
            right = mid - 1

        else:
            left =  mid + 1

    print(f"Not Found The item {item}")

# %%
binary_search(list,4)
# Out:
# 'Found the item 4'

# %% [markdown]
# **Given two strings A and B, you need to find the last occurrence ( 1 based indexing) of string B in string A.**

# %%
A = "abcdefghijklghifghsd"
B = "ghi"

# %%
A.rfind(B) + 1
# Out:
# 13

# %% [markdown]
# **If the pattern is present in the given string**

# %%
txt = "abcdefh"
pat = "bcd"

if pat in txt:
    print('True')
else:
    print('False')
# Out:
# True
