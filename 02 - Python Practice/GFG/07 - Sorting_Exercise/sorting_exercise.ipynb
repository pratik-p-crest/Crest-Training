# %% [markdown]
# **1. Sort a String**
#
# Given a string consisting of lowercase letters, arrange all its letters in ascending order.
#
# Examples:
#
# Input:
# S = "edcab"
# Output: "abcde"
#
# Input:
# S = "xzy"
# Output: "xyz"

# %%
s = 'avhvhaf'

s = list(s)
s.sort()
''.join(s)
# Out:
# 'aafhhvv'

# %% [markdown]
# **2. Insertion Sort**

# %%
def insertion_sort(arr):
    size = len(arr)
    for i in range(1,size):
        if arr[i] < arr[i-1]:
            arr[i] , arr[i-1] = arr[i-1] , arr[i]
            j = i
            while j > 0:
                if arr[j-1] > arr[j]:
                    arr[j] , arr[j-1] = arr[j-1] , arr[j]
                j -= 1

# %%
l = [1,5,48,3,31,44,354,635]
print('before sorting \n',l)
print(insertion_sort(l))
print('\nafter sorting \n',l)
# Out:
# before sorting
#  [1, 5, 48, 3, 31, 44, 354, 635]
# None
#
# after sorting
#  [1, 3, 5, 31, 44, 48, 354, 635]

# %% [markdown]
# **3. Selection Sort**

# %%
def selection_sort(array):

    size = len(arr)
    for ind in range(size):
        min_index = ind

        for j in range(ind + 1, size):
            if array[j] < array[min_index]:
                min_index = j

        array[ind], array[min_index] = array[min_index], array[ind]

# %%
arr = [6,6,2,12,5,1,3]
print("Unsorted list is:")
print(arr)

selection_sort(arr)

print("Sorted list is:")
print(arr)
# Out:
# Unsorted list is:
# [6, 6, 2, 12, 5, 1, 3]
# Sorted list is:
# [1, 2, 3, 5, 6, 6, 12]

# %% [markdown]
# **4. Quick Sort**

# %%
def quick_sort(a, low, high):
    if low < high:
        pi = partition(a, low, high)
        quick_sort(a, low, pi - 1)
        quick_sort(a, pi + 1, high)

def partition(a, low, high):
    pivot = a[high]
    i = low - 1

    for j in range(low, high):
        if a[j] <= pivot:
            i += 1
            a[i], a[j] = a[j], a[i]

    a[i + 1], a[high] = a[high], a[i + 1]
    return i + 1

# %%
arr = [45,6,851,542,35,64,112,85,2]
print("Unsorted list is:")
print(arr)

quick_sort(arr,0,len(arr)-1)

print("Sorted list is:")
print(arr)
# Out:
# Unsorted list is:
# [45, 6, 851, 542, 35, 64, 112, 85, 2]
# Sorted list is:
# [2, 6, 35, 45, 64, 85, 112, 542, 851]
