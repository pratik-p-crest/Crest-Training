# %% [markdown]
# **Date Formatting:**
#
# 1. Write a Python program to format the current date and time as "YYYY-MM-DD HH:mm:ss" using Pendulum module.

# %%
import pendulum

# %%
now = pendulum.now()

formatted_date = now.format("YYYY-MM-DD HH:mm:ss")
print(formatted_date)
# Out:
# 2026-01-16 11:44:42
