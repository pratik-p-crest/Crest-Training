# %% [markdown]
# **1. Counter of Vowels**
#
# Write a Python program that creates a counter of the vowels in the word "Python Exercises".

# %%
from collections import Counter

# %%
text = "Python Exercises"
vowels = "aeiou"

vowel_count = Counter(char for char in text.lower() if char in vowels)

print(vowel_count)
# Out:
# Counter({'e': 3, 'o': 1, 'i': 1})
