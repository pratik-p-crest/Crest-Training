# %% [markdown]
# **1. String to Bytes Conversion**
#
# Write a Python program to convert a given string to bytes using different encodings like UTF-8, UTF-16, ASCII etc.

# %%
text = "Hello Python"

utf8_bytes = text.encode("utf-8")
utf16_bytes = text.encode("utf-16")
ascii_bytes = text.encode("ascii")

print("UTF-8 :", utf8_bytes)
print("UTF-16:", utf16_bytes)
print("ASCII :", ascii_bytes)
# Out:
# UTF-8 : b'Hello Python'
# UTF-16: b'\xff\xfeH\x00e\x00l\x00l\x00o\x00 \x00P\x00y\x00t\x00h\x00o\x00n\x00'
# ASCII : b'Hello Python'
