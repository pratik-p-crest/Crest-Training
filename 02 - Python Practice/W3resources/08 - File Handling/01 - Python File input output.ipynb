# %% [markdown]
# **1. Read Entire File**
#
# Write a Python program to read an entire text file.

# %%
txt = open('test.txt')
print(txt.read())
# Out:
# Hello!
# This is a Test file which is stored in File Handling Folder.

# %% [markdown]
# **2. Write List to File**
#
# Write a Python program to write a list to a file.

# %%
my_list = ['Python', 'Java', 'C++', 'JavaScript']

with open('output.txt', 'w') as file:
    for item in my_list:
        file.write(item + '\n')

# %% [markdown]
# **3. Longest Words Finder**
#
# Write a python program to find the longest words.

# %%
def longest_words_from_file(filename):
    with open(filename, 'r') as file:
        text = file.read()

    words = text.split()

    if not words:
        return []

    max_len = max(len(word) for word in words)
    return [word for word in words if len(word) == max_len]


result = longest_words_from_file("test.txt")
print(result)
# Out:
# ['Handling']
